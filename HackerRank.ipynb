# %%
# the loop will go into infinite mode
i = 1
while True:
    if i % 2 == 0:
        break
    else:
        print(i, end= '')
    i = i+2

# %%
# no output
x = 'abcdef'
i = 'i'
while i in x:
    print(i)

# %%
# the loop will go into infinite mode
x = 'abcdefi'
i = 'i'
while i in x:
    print(i)

# %%
x = 'abcdef'
i = 'a'
while i in x:
    x = x[1:]
    print(i, end = '')
# Out:
# a

# %%
x = 'abcdef'
i = 'c'
while i in x:
    x = x[1:]
    print(i, end = '')
# Out:
# ccc

# %%
x = 'abcdef'
for i in x:
        print(i, end = '')
        x.upper()
# Out:
# abcdef

# %%
True = False
# Out:
#   File "C:\Users\e105301\AppData\Local\Temp/ipykernel_20912/1601851819.py", line 1
#     True = False
#     ^
# SyntaxError: cannot assign to True

# %%
# infinite loop

i = 2
while True:
    if i % 3 ==0:
        break
print(i, end= '')
i = i+2
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20912/1542835373.py in <module>
#       3 i = 2
#       4 while True:
# ----> 5     if i % 3 ==0:
#       6         break
#       7 print(i, end= '')
#
# KeyboardInterrupt:

# %%
i = 2
while True:
    if i % 3 ==0:
        break
    else:
        print('infinite')
print(i, end= '')
i = i+2
# Out:
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# infinite
# ...

# %%
row =10
col=10
for i in range(0,row):
    for j in range(0,col):
        if((j == 0 or j == col-1) and (i!=0 and i!=row-1)) :
            print('*',end='')   #end='' so that print statement should not change the line.
        elif( ((i==0 or i==row-1) and (j>0 and j<col-1))):
            print('*',end= ' ')
        else:
            print(end='  ')  #to print the space.
    print()  #to change the line after iteration of inner loop.
# Out:
#   * * * * * * * *
# *                *
# *                *
# *                *
# *                *
# *                *
# *                *
# *                *
# *                *
#   * * * * * * * *

# %%
list(reversed([1,2,3]))
# Out:
# [3, 2, 1]

# %%
my_list = [57 ,57 ,-57 ,57]

# %%
import numpy as np
np.unique(my_list)[-2]
# Out:
# -57

# %%
my_list1 = [1,2,4,4, -1, -3,5,5,6,6]
ls = [2 ,3 ,6, 6,5]

# %%
print(np.unique(ls)[-2])
# Out:
# 5

# %%
print(my_list1.sort())
# Out:
# None

# %%
set(my_list,)
# Out:
# {-57, 57}

# %%
my_list2 = [-1, -2, -2, -3,0, 2 ]
np.unique(my_list2)
# Out:
# array([-3, -2, -1,  0,  2])

# %%
sorted(my_list1)
# Out:
# [-3, -1, 1, 2, 4, 4, 5, 5, 6, 6]

# %%
n = int(input())
arr = input().split()
list(arr)
# Out:
# 12
# 12455
# ['12455']

# %%
if __name__ == '__main__':
    n = int(input())
    arr = map(int, input().split())
    ls = list(arr)
    ls
    #print(np.unique(x)[-2])
    print(np.unique(ls)[-2])
# Out:
# 1
# 2 3 6 6 5
# 5

# %%
2 3 6 6 5
# Out:
# [5, 6, 6, 5, 5]

# %%
if __name__ == '__main__':
    n = int(input())
    arr = map(int, input().split())
    ls = list(arr)
    print (sorted(set(arr))[-2])
# Out:
# 1
# 2 3 6 6 5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_33060/3600300719.py in <module>
#       3     arr = map(int, input().split())
#       4     ls = list(arr)
# ----> 5     print (sorted(set(arr))[-2])
#
# IndexError: list index out of range

# %%
#https://wdl-data.fra1.digitaloceanspaces.com/lisbon%2Fficheiros_WDL.zop

import pandas as pd
from zipfile import ZipFile

# %%
pfile_name = 'https://wdl-data.fra1.digitaloceanspaces.com/lisbon%2Fficheiros_WDL.zop'

# %%
import geopandas as gpd

# %%
#!pip install --proxy=http://e105301:RRPS_Tvil@s2022@webgateway.emea.mtufn.com:9090 geopandas

# %%
df_dicofre = gpd.read_file('https://wdl-data.fra1.digitaloceanspaces.com/lisbon%2Fficheiros_WDL.zip')
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1345             try:
# -> 1346                 h.request(req.get_method(), req.selector, req.data, headers,
#    1347                           encode_chunked=req.has_header('Transfer-encoding'))
#
# ~\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1278         """Send a complete request to the server."""
# -> 1279         self._send_request(method, url, body, headers, encode_chunked)
#    1280
#
# ~\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1324             body = _encode(body, 'body')
# -> 1325         self.endheaders(body, encode_chunked=encode_chunked)
#    1326
#
# ...
